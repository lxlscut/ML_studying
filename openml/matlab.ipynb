# %%
import numpy as np

# %%
a = np.linspace(10,20,100)
a
# Out:
# array([10.        , 10.1010101 , 10.2020202 , 10.3030303 , 10.4040404 ,
#        10.50505051, 10.60606061, 10.70707071, 10.80808081, 10.90909091,
#        11.01010101, 11.11111111, 11.21212121, 11.31313131, 11.41414141,
#        11.51515152, 11.61616162, 11.71717172, 11.81818182, 11.91919192,
#        12.02020202, 12.12121212, 12.22222222, 12.32323232, 12.42424242,
#        12.52525253, 12.62626263, 12.72727273, 12.82828283, 12.92929293,
#        13.03030303, 13.13131313, 13.23232323, 13.33333333, 13.43434343,
#        13.53535354, 13.63636364, 13.73737374, 13.83838384, 13.93939394,
#        14.04040404, 14.14141414, 14.24242424, 14.34343434, 14.44444444,
#        14.54545455, 14.64646465, 14.74747475, 14.84848485, 14.94949495,
#        15.05050505, 15.15151515, 15.25252525, 15.35353535, 15.45454545,
#        15.55555556, 15.65656566, 15.75757576, 15.85858586, 15.95959596,
#        16.06060606, 16.16161616, 16.26262626, 16.36363636, 16.46464646,
# ...

# %%
b = 1/a
b
# Out:
# array([0.1       , 0.099     , 0.0980198 , 0.09705882, 0.0961165 ,
#        0.09519231, 0.09428571, 0.09339623, 0.09252336, 0.09166667,
#        0.09082569, 0.09      , 0.08918919, 0.08839286, 0.08761062,
#        0.08684211, 0.08608696, 0.08534483, 0.08461538, 0.08389831,
#        0.08319328, 0.0825    , 0.08181818, 0.08114754, 0.0804878 ,
#        0.07983871, 0.0792    , 0.07857143, 0.07795276, 0.07734375,
#        0.07674419, 0.07615385, 0.07557252, 0.075     , 0.07443609,
#        0.0738806 , 0.07333333, 0.07279412, 0.07226277, 0.07173913,
#        0.07122302, 0.07071429, 0.07021277, 0.06971831, 0.06923077,
#        0.06875   , 0.06827586, 0.06780822, 0.06734694, 0.06689189,
#        0.06644295, 0.066     , 0.06556291, 0.06513158, 0.06470588,
#        0.06428571, 0.06387097, 0.06346154, 0.06305732, 0.06265823,
#        0.06226415, 0.061875  , 0.06149068, 0.06111111, 0.0607362 ,
#        0.06036585, 0.06      , 0.05963855, 0.05928144, 0.05892857,
# ...
